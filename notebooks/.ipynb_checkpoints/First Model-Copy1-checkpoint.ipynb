# %%
#Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Data

# %%
Events = pd.read_csv('../data/raw/HistoricalEvents/MEvents2019.csv')

#Transformation - There are some records where Events Team Id is zero there are very few cases so we're deleting such records
# Query to find out such records: check one following case:
# Events[(Events['WTeamID']==1438) & (Events['LTeamID']==1120) & (Events['EventTeamID']==0)]

Events = Events[Events['EventTeamID']>0]

# %%
print(f"We have {Events.EventType.nunique()} unique values in EvenType and \
{Events.EventSubType.nunique()} unique values in EventSubType")
# Out:
# We have 16 unique values in EvenType and 51 unique values in EventSubType

# %%
Events.head()
# Out:
#     EventID  Season  DayNum  WTeamID  LTeamID  WFinalScore  LFinalScore  \
# 0  10442717    2019       1     1104     1380           82           62
# 1  10442718    2019       1     1104     1380           82           62
# 2  10442719    2019       1     1104     1380           82           62
# 3  10442720    2019       1     1104     1380           82           62
# 4  10442721    2019       1     1104     1380           82           62
#
#    WCurrentScore  LCurrentScore  ElapsedSeconds  EventTeamID  EventPlayerID  \
# 0              0              0              18         1380          10314
# 1              0              0              18         1380          10307
# 2              0              0              42         1104            129
# 3              0              0              58         1380          10303
# 4              0              0              63         1104            143
#
#   EventType EventSubType  X  Y  Area
# 0     made2         jump  0  0     0
# ...

# %% [markdown]
# We are keeping following features only in events table:

# %% [markdown]
# ### Data Transformation

# %%
Events = Events[['Season','DayNum','WTeamID','LTeamID','WFinalScore','LFinalScore', 'EventTeamID','EventType']]

# %%
Events.head()
# Out:
#    Season  DayNum  WTeamID  LTeamID  WFinalScore  LFinalScore  EventTeamID  \
# 0    2019       1     1104     1380           82           62         1380
# 1    2019       1     1104     1380           82           62         1380
# 2    2019       1     1104     1380           82           62         1104
# 3    2019       1     1104     1380           82           62         1380
# 4    2019       1     1104     1380           82           62         1104
#
#   EventType
# 0     made2
# 1    assist
# 2     made2
# 3  turnover
# 4     made3

# %%
Events_grp = Events.groupby(list(Events.columns))['EventType'].count()

# %%
Events_grp.rename(columns={'EventType':'Count'}, inplace=True)
# Out:
# Season  DayNum  WTeamID  LTeamID  WFinalScore  LFinalScore  EventTeamID  EventType
# 2019    1       1104     1380     82           62           1104         assist       17
#                                                                          block         6
#                                                                          foul         24
#                                                                          made1        19
#                                                                          made2        18
#                                                                                       ..
#         152     1438     1120     63           62           1438         reb          34
#                                                                          steal         1
#                                                                          sub          32
#                                                                          timeout       2
# ...

# %%
Events_grp = Events_grp.reset_index()

# %%
Events_grp.rename(columns={0:"Count"}, inplace=True)

# %%
Events_grp.tail()
# Out:
#         Season  DayNum  WTeamID  LTeamID  WFinalScore  LFinalScore  \
# 163839    2019     152     1438     1120           63           62
# 163840    2019     152     1438     1120           63           62
# 163841    2019     152     1438     1120           63           62
# 163842    2019     152     1438     1120           63           62
# 163843    2019     152     1438     1120           63           62
#
#         EventTeamID EventType  Count
# 163839         1438       reb     34
# 163840         1438     steal      1
# 163841         1438       sub     32
# 163842         1438   timeout      2
# 163843         1438  turnover      8

# %%
Events_grp['Team1'] = Events_grp[['WTeamID','LTeamID']].apply(min, axis=1)
Events_grp['Team2'] = Events_grp[['WTeamID','LTeamID']].apply(max, axis=1)

# %%
Events_grp['EventTeamID'] = Events_grp.apply(lambda x: 'T1' if x['Team1']==x['EventTeamID'] else 'T2', axis=1)

# %%
Events_grp['EventType'] = Events_grp.apply(lambda x: (x['EventTeamID']+ '_' + x['EventType']), axis=1)

# %%
Events_grp.drop(['EventTeamID'], axis=1, inplace=True)

# %%
Events_grp.tail()
# Out:
#         Season  DayNum  WTeamID  LTeamID  WFinalScore  LFinalScore  \
# 163839    2019     152     1438     1120           63           62
# 163840    2019     152     1438     1120           63           62
# 163841    2019     152     1438     1120           63           62
# 163842    2019     152     1438     1120           63           62
# 163843    2019     152     1438     1120           63           62
#
#           EventType  Count  Team1  Team2
# 163839       T2_reb     34   1120   1438
# 163840     T2_steal      1   1120   1438
# 163841       T2_sub     32   1120   1438
# 163842   T2_timeout      2   1120   1438
# 163843  T2_turnover      8   1120   1438

# %%
data = pd.pivot_table(Events_grp,index=['Season','DayNum','WTeamID', 'LTeamID', 'WFinalScore', 'LFinalScore',
       'Team1', 'Team2'], columns=['EventType'], values='Count').fillna(0).reset_index()

# %%
data.head()
# Out:
# EventType  Season  DayNum  WTeamID  LTeamID  WFinalScore  LFinalScore  Team1  \
# 0            2019       1     1104     1380           82           62   1104
# 1            2019       1     1113     1168          102           94   1113
# 2            2019       1     1119     1265           73           69   1119
# 3            2019       1     1120     1375          101           58   1120
# 4            2019       1     1123     1232           86           69   1123
#
# EventType  Team2  T1_assist  T1_block  ...  T2_made2  T2_made3  T2_miss1  \
# 0           1380       17.0       6.0  ...      18.0       3.0      13.0
# 1           1168       11.0       2.0  ...      27.0       7.0       7.0
# 2           1265       14.0       1.0  ...      24.0       3.0      12.0
# 3           1375       24.0       8.0  ...      10.0       7.0       5.0
# 4           1232       14.0       5.0  ...      20.0       6.0       7.0
#
# ...

# %%
data.columns.values
# Out:
# array(['Season', 'DayNum', 'WTeamID', 'LTeamID', 'WFinalScore',
#        'LFinalScore', 'Team1', 'Team2', 'T1_assist', 'T1_block',
#        'T1_foul', 'T1_fouled', 'T1_jumpb', 'T1_made1', 'T1_made2',
#        'T1_made3', 'T1_miss1', 'T1_miss2', 'T1_miss3', 'T1_reb',
#        'T1_steal', 'T1_sub', 'T1_timeout', 'T1_turnover', 'T2_assist',
#        'T2_block', 'T2_foul', 'T2_fouled', 'T2_jumpb', 'T2_made1',
#        'T2_made2', 'T2_made3', 'T2_miss1', 'T2_miss2', 'T2_miss3',
#        'T2_reb', 'T2_steal', 'T2_sub', 'T2_timeout', 'T2_turnover'],
#       dtype=object)

# %%
data['results'] = data.apply(lambda x: 1 if x['WTeamID']==x['Team1'] else 0, axis=1)

# %%
data['T1Score'] = data.apply(lambda x: x['WFinalScore'] if x['WTeamID']==x['Team1'] else x['LFinalScore'], axis=1)
data['T2Score'] = data.apply(lambda x: x['WFinalScore'] if x['WTeamID']==x['Team2'] else x['LFinalScore'], axis=1)

# %%
data.drop(['WTeamID','LTeamID','WFinalScore','LFinalScore'], axis=1, inplace=True)

# %% [markdown]
# ### Data Imbalance

# %%
data.results.value_counts()
# Out:
# 0    2879
# 1    2718
# Name: results, dtype: int64

# %%
# ---- Found one case having multiple matches for a same team combination -------
# data[(data['WTeamID']==1378) & (data['LTeamID']==1177)]
# data[(data['LTeamID']==1378) & (data['WTeamID']==1177)]

# %%
data.columns
# Out:
# Index(['Season', 'DayNum', 'Team1', 'Team2', 'T1_assist', 'T1_block',
#        'T1_foul', 'T1_fouled', 'T1_jumpb', 'T1_made1', 'T1_made2', 'T1_made3',
#        'T1_miss1', 'T1_miss2', 'T1_miss3', 'T1_reb', 'T1_steal', 'T1_sub',
#        'T1_timeout', 'T1_turnover', 'T2_assist', 'T2_block', 'T2_foul',
#        'T2_fouled', 'T2_jumpb', 'T2_made1', 'T2_made2', 'T2_made3', 'T2_miss1',
#        'T2_miss2', 'T2_miss3', 'T2_reb', 'T2_steal', 'T2_sub', 'T2_timeout',
#        'T2_turnover', 'results', 'T1Score', 'T2Score'],
#       dtype='object', name='EventType')

# %%
# Code to calculate the difference between the rows - DONOT DELETE AS OF NOW ------
# data_temp = data.sort_values(by=['Season', 'DayNum', 'WTeamID', 'LTeamID', 'Team1', 'Team2',
#        'WFinalScore', 'LFinalScore', 'EventTeamID'], ascending=[True,True,True,True,True,True,True,True,False]).head()

# data.groupby(['Season', 'DayNum', 'WTeamID', 'LTeamID', 'Team1', 'Team2',
#        'WFinalScore', 'LFinalScore']).diff().dropna()

# %%
data.head()
# Out:
# EventType  Season  DayNum  Team1  Team2  T1_assist  T1_block  T1_foul  \
# 0            2019       1   1104   1380       17.0       6.0     24.0
# 1            2019       1   1113   1168       11.0       2.0     26.0
# 2            2019       1   1119   1265       14.0       1.0     22.0
# 3            2019       1   1120   1375       24.0       8.0     21.0
# 4            2019       1   1123   1232       14.0       5.0     18.0
#
# EventType  T1_fouled  T1_jumpb  T1_made1  ...  T2_miss2  T2_miss3  T2_reb  \
# 0                0.0       0.0      19.0  ...      20.0      14.0    38.0
# 1                0.0       0.0      26.0  ...      23.0      17.0    44.0
# 2                0.0       0.0      20.0  ...      13.0      12.0    42.0
# 3                0.0       0.0       7.0  ...      14.0      15.0    29.0
# 4               20.0       2.0      15.0  ...      35.0       6.0    42.0
#
# EventType  T2_steal  T2_sub  T2_timeout  T2_turnover  results  T1Score  \
# ...

# %%
data.shape
# Out:
# (5597, 39)

# %%
data.groupby(['Team1','Team2'])['Season'].count().sort_values(ascending=False).reset_index()['Season'].value_counts()
# Out:
# 1    2590
# 2    1172
# 3     221
# Name: Season, dtype: int64

# %% [markdown]
# ### Compact Results

# %%
tourney_result = pd.read_csv('../data/raw/MDataFiles_Stage1/MNCAATourneyCompactResults.csv')
reg_tourney_result = pd.read_csv('../data/raw/MDataFiles_Stage1/MRegularSeasonCompactResults.csv')
sec_tourney_result = pd.read_csv('../data/raw/MDataFiles_Stage1/MSecondaryTourneyCompactResults.csv')

# %%
tourney_result.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1985     136     1116      63     1234      54    N      0
# 1    1985     136     1120      59     1345      58    N      0
# 2    1985     136     1207      68     1250      43    N      0
# 3    1985     136     1229      58     1425      55    N      0
# 4    1985     136     1242      49     1325      38    N      0

# %%
tourney_result.DayNum.describe()
# Out:
# count    2251.000000
# mean      139.139049
# std         4.211069
# min       134.000000
# 25%       136.000000
# 50%       137.000000
# 75%       139.000000
# max       154.000000
# Name: DayNum, dtype: float64

# %%
reg_tourney_result.DayNum.describe()
# Out:
# count    161552.000000
# mean         74.665359
# std          33.670352
# min           0.000000
# 25%          47.000000
# 50%          77.000000
# 75%         103.000000
# max         132.000000
# Name: DayNum, dtype: float64

# %%
sec_tourney_result.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  \
# 0    1985     136     1151      67     1155      65    H      0
# 1    1985     136     1153      77     1245      61    H      0
# 2    1985     136     1201      79     1365      76    H      0
# 3    1985     136     1231      79     1139      57    H      0
# 4    1985     136     1249      78     1222      71    H      0
#
#   SecondaryTourney
# 0              NIT
# 1              NIT
# 2              NIT
# 3              NIT
# 4              NIT

# %%
sec_tourney_result.DayNum.describe()
# Out:
# count    1624.000000
# mean      138.670567
# std         4.649830
# min       133.000000
# 25%       135.000000
# 50%       137.000000
# 75%       141.000000
# max       152.000000
# Name: DayNum, dtype: float64

# %%
tourney_seed = pd.read_csv('../data/raw/MDataFiles_Stage1/MNCAATourneySeeds.csv')

# %%
tourney_result = tourney_result.drop(['DayNum', 'WScore', 'LScore', 'WLoc', 'NumOT'], axis=1)
tourney_result
# Out:
#       Season  WTeamID  LTeamID
# 0       1985     1116     1234
# 1       1985     1120     1345
# 2       1985     1207     1250
# 3       1985     1229     1425
# 4       1985     1242     1325
# ...      ...      ...      ...
# 2246    2019     1120     1246
# 2247    2019     1277     1181
# 2248    2019     1403     1277
# 2249    2019     1438     1120
# 2250    2019     1438     1403
#
# [2251 rows x 3 columns]

# %% [markdown]
# ### Merge Seed

# %%
tourney_result = pd.merge(tourney_result, tourney_seed, left_on=['Season', 'WTeamID'], right_on=['Season', 'TeamID'], how='left')
tourney_result.rename(columns={'Seed':'WSeed'}, inplace=True)
tourney_result = tourney_result.drop('TeamID', axis=1)
tourney_result = pd.merge(tourney_result, tourney_seed, left_on=['Season', 'LTeamID'], right_on=['Season', 'TeamID'], how='left')
tourney_result.rename(columns={'Seed':'LSeed'}, inplace=True)
tourney_result = tourney_result.drop('TeamID', axis=1)
tourney_result
# Out:
#       Season  WTeamID  LTeamID WSeed LSeed
# 0       1985     1116     1234   X09   X08
# 1       1985     1120     1345   Z11   Z06
# 2       1985     1207     1250   W01   W16
# 3       1985     1229     1425   Y09   Y08
# 4       1985     1242     1325   Z03   Z14
# ...      ...      ...      ...   ...   ...
# 2246    2019     1120     1246   Y05   Y02
# 2247    2019     1277     1181   W02   W01
# 2248    2019     1403     1277   X03   W02
# 2249    2019     1438     1120   Z01   Y05
# 2250    2019     1438     1403   Z01   X03
#
# [2251 rows x 5 columns]

# %%
def get_seed(x):
    return int(x[1:3])

tourney_result['WSeed'] = tourney_result['WSeed'].map(lambda x: get_seed(x))
tourney_result['LSeed'] = tourney_result['LSeed'].map(lambda x: get_seed(x))
tourney_result
# Out:
#       Season  WTeamID  LTeamID  WSeed  LSeed
# 0       1985     1116     1234      9      8
# 1       1985     1120     1345     11      6
# 2       1985     1207     1250      1     16
# 3       1985     1229     1425      9      8
# 4       1985     1242     1325      3     14
# ...      ...      ...      ...    ...    ...
# 2246    2019     1120     1246      5      2
# 2247    2019     1277     1181      2      1
# 2248    2019     1403     1277      3      2
# 2249    2019     1438     1120      1      5
# 2250    2019     1438     1403      1      3
#
# [2251 rows x 5 columns]

# %% [markdown]
# ### Merge Score

# %%
season_result = pd.read_csv('../data/raw/MDataFiles_Stage1/MRegularSeasonCompactResults.csv')

# %%
season_result.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1985      20     1228      81     1328      64    N      0
# 1    1985      25     1106      77     1354      70    H      0
# 2    1985      25     1112      63     1223      56    H      0
# 3    1985      25     1165      70     1432      54    H      0
# 4    1985      25     1192      86     1447      74    H      0

# %%
season_win_result = season_result[['Season', 'WTeamID', 'WScore']]
season_lose_result = season_result[['Season', 'LTeamID', 'LScore']]
season_win_result.rename(columns={'WTeamID':'TeamID', 'WScore':'Score'}, inplace=True)
season_lose_result.rename(columns={'LTeamID':'TeamID', 'LScore':'Score'}, inplace=True)
season_result = pd.concat((season_win_result, season_lose_result)).reset_index(drop=True)
season_result
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#         Season  TeamID  Score
# 0         1985    1228     81
# 1         1985    1106     77
# 2         1985    1112     63
# 3         1985    1165     70
# 4         1985    1192     86
# ...        ...     ...    ...
# 323099    2019    1222     57
# 323100    2019    1426     64
# 323101    2019    1276     60
# 323102    2019    1382     53
# 323103    2019    1217     85
#
# [323104 rows x 3 columns]

# %%
season_score = season_result.groupby(['Season', 'TeamID'])['Score'].sum().reset_index()
season_score
# Out:
#        Season  TeamID  Score
# 0        1985    1102   1514
# 1        1985    1103   1404
# 2        1985    1104   2055
# 3        1985    1106   1719
# 4        1985    1108   2075
# ...       ...     ...    ...
# 11236    2019    1462   2372
# 11237    2019    1463   2265
# 11238    2019    1464   2205
# 11239    2019    1465   1962
# 11240    2019    1466   1903
#
# [11241 rows x 3 columns]

# %%
tourney_result = pd.merge(tourney_result, season_score, left_on=['Season', 'WTeamID'], right_on=['Season', 'TeamID'], how='left')
tourney_result.rename(columns={'Score':'WScoreT'}, inplace=True)
tourney_result = tourney_result.drop('TeamID', axis=1)
tourney_result = pd.merge(tourney_result, season_score, left_on=['Season', 'LTeamID'], right_on=['Season', 'TeamID'], how='left')
tourney_result.rename(columns={'Score':'LScoreT'}, inplace=True)
tourney_result = tourney_result.drop('TeamID', axis=1)
tourney_result
# Out:
#       Season  WTeamID  LTeamID  WSeed  LSeed  WScoreT  LScoreT
# 0       1985     1116     1234      9      8     2156     2092
# 1       1985     1120     1345     11      6     2040     1728
# 2       1985     1207     1250      1     16     2045     1907
# 3       1985     1229     1425      9      8     1933     1915
# 4       1985     1242     1325      3     14     2281     1824
# ...      ...      ...      ...    ...    ...      ...      ...
# 2246    2019     1120     1246      5      2     2682     2532
# 2247    2019     1277     1181      2      1     2680     2839
# 2248    2019     1403     1277      3      2     2339     2680
# 2249    2019     1438     1120      1      5     2299     2682
# 2250    2019     1438     1403      1      3     2299     2339
#
# [2251 rows x 7 columns]

# %%
tourney_win_result = tourney_result.drop(['Season', 'WTeamID', 'LTeamID'], axis=1)
tourney_win_result.rename(columns={'WSeed':'Seed1', 'LSeed':'Seed2', 'WScoreT':'ScoreT1', 'LScoreT':'ScoreT2'}, inplace=True)
tourney_win_result
# Out:
#       Seed1  Seed2  ScoreT1  ScoreT2
# 0         9      8     2156     2092
# 1        11      6     2040     1728
# 2         1     16     2045     1907
# 3         9      8     1933     1915
# 4         3     14     2281     1824
# ...     ...    ...      ...      ...
# 2246      5      2     2682     2532
# 2247      2      1     2680     2839
# 2248      3      2     2339     2680
# 2249      1      5     2299     2682
# 2250      1      3     2299     2339
#
# [2251 rows x 4 columns]

# %%
tourney_lose_result = tourney_win_result.copy()
tourney_lose_result['Seed1'] = tourney_win_result['Seed2']
tourney_lose_result['Seed2'] = tourney_win_result['Seed1']
tourney_lose_result['ScoreT1'] = tourney_win_result['ScoreT2']
tourney_lose_result['ScoreT2'] = tourney_win_result['ScoreT1']
tourney_lose_result
# Out:
#       Seed1  Seed2  ScoreT1  ScoreT2
# 0         8      9     2092     2156
# 1         6     11     1728     2040
# 2        16      1     1907     2045
# 3         8      9     1915     1933
# 4        14      3     1824     2281
# ...     ...    ...      ...      ...
# 2246      2      5     2532     2682
# 2247      1      2     2839     2680
# 2248      2      3     2680     2339
# 2249      5      1     2682     2299
# 2250      3      1     2339     2299
#
# [2251 rows x 4 columns]

# %% [markdown]
# ### Preparing Training Dataset

# %%
tourney_win_result['Seed_diff'] = tourney_win_result['Seed1'] - tourney_win_result['Seed2']
tourney_win_result['ScoreT_diff'] = tourney_win_result['ScoreT1'] - tourney_win_result['ScoreT2']
tourney_lose_result['Seed_diff'] = tourney_lose_result['Seed1'] - tourney_lose_result['Seed2']
tourney_lose_result['ScoreT_diff'] = tourney_lose_result['ScoreT1'] - tourney_lose_result['ScoreT2']

# %%
tourney_win_result['result'] = 1
tourney_lose_result['result'] = 0
tourney_result = pd.concat((tourney_win_result, tourney_lose_result)).reset_index(drop=True)
tourney_result
# Out:
#       Seed1  Seed2  ScoreT1  ScoreT2  Seed_diff  ScoreT_diff  result
# 0         9      8     2156     2092          1           64       1
# 1        11      6     2040     1728          5          312       1
# 2         1     16     2045     1907        -15          138       1
# 3         9      8     1933     1915          1           18       1
# 4         3     14     2281     1824        -11          457       1
# ...     ...    ...      ...      ...        ...          ...     ...
# 4497      2      5     2532     2682         -3         -150       0
# 4498      1      2     2839     2680         -1          159       0
# 4499      2      3     2680     2339         -1          341       0
# 4500      5      1     2682     2299          4          383       0
# 4501      3      1     2339     2299          2           40       0
#
# [4502 rows x 7 columns]

# %% [markdown]
# ### Preparing Test Data

# %%
test_df = pd.read_csv('../data/raw/MSampleSubmissionStage1_2020.csv')

# %%
test_df['Season'] = test_df['ID'].map(lambda x: int(x[:4]))
test_df['WTeamID'] = test_df['ID'].map(lambda x: int(x[5:9]))
test_df['LTeamID'] = test_df['ID'].map(lambda x: int(x[10:14]))
test_df
# Out:
#                    ID  Pred  Season  WTeamID  LTeamID
# 0      2015_1107_1112   0.5    2015     1107     1112
# 1      2015_1107_1116   0.5    2015     1107     1116
# 2      2015_1107_1124   0.5    2015     1107     1124
# 3      2015_1107_1125   0.5    2015     1107     1125
# 4      2015_1107_1129   0.5    2015     1107     1129
# ...               ...   ...     ...      ...      ...
# 11385  2019_1449_1459   0.5    2019     1449     1459
# 11386  2019_1449_1463   0.5    2019     1449     1463
# 11387  2019_1458_1459   0.5    2019     1458     1459
# 11388  2019_1458_1463   0.5    2019     1458     1463
# 11389  2019_1459_1463   0.5    2019     1459     1463
#
# [11390 rows x 5 columns]

# %%
test_df = pd.merge(test_df, tourney_seed, left_on=['Season', 'WTeamID'], right_on=['Season', 'TeamID'], how='left')
test_df.rename(columns={'Seed':'Seed1'}, inplace=True)
test_df = test_df.drop('TeamID', axis=1)
test_df = pd.merge(test_df, tourney_seed, left_on=['Season', 'LTeamID'], right_on=['Season', 'TeamID'], how='left')
test_df.rename(columns={'Seed':'Seed2'}, inplace=True)
test_df = test_df.drop('TeamID', axis=1)
test_df = pd.merge(test_df, season_score, left_on=['Season', 'WTeamID'], right_on=['Season', 'TeamID'], how='left')
test_df.rename(columns={'Score':'ScoreT1'}, inplace=True)
test_df = test_df.drop('TeamID', axis=1)
test_df = pd.merge(test_df, season_score, left_on=['Season', 'LTeamID'], right_on=['Season', 'TeamID'], how='left')
test_df.rename(columns={'Score':'ScoreT2'}, inplace=True)
test_df = test_df.drop('TeamID', axis=1)
test_df
# Out:
#                    ID  Pred  Season  WTeamID  LTeamID Seed1 Seed2  ScoreT1  \
# 0      2015_1107_1112   0.5    2015     1107     1112   W14   Z02     2096
# 1      2015_1107_1116   0.5    2015     1107     1116   W14   Z05     2096
# 2      2015_1107_1124   0.5    2015     1107     1124   W14   Z03     2096
# 3      2015_1107_1125   0.5    2015     1107     1125   W14   W15     2096
# 4      2015_1107_1129   0.5    2015     1107     1129   W14  W11a     2096
# ...               ...   ...     ...      ...      ...   ...   ...      ...
# 11385  2019_1449_1459   0.5    2019     1449     1459   Y09   Y07     2374
# 11386  2019_1449_1463   0.5    2019     1449     1463   Y09   W14     2374
# 11387  2019_1458_1459   0.5    2019     1458     1459   Z05   Y07     2279
# 11388  2019_1458_1463   0.5    2019     1458     1463   Z05   W14     2279
# 11389  2019_1459_1463   0.5    2019     1459     1463   Y07   W14     2436
#
#        ScoreT2
# 0         2599
# 1         2653
# 2         2212
# ...

# %%
test_df['Seed1'] = test_df['Seed1'].map(lambda x: get_seed(x))
test_df['Seed2'] = test_df['Seed2'].map(lambda x: get_seed(x))
test_df['Seed_diff'] = test_df['Seed1'] - test_df['Seed2']
test_df['ScoreT_diff'] = test_df['ScoreT1'] - test_df['ScoreT2']
test_df = test_df.drop(['ID', 'Pred', 'Season', 'WTeamID', 'LTeamID'], axis=1)
test_df
# Out:
#        Seed1  Seed2  ScoreT1  ScoreT2  Seed_diff  ScoreT_diff
# 0         14      2     2096     2599         12         -503
# 1         14      5     2096     2653          9         -557
# 2         14      3     2096     2212         11         -116
# 3         14     15     2096     2287         -1         -191
# 4         14     11     2096     2166          3          -70
# ...      ...    ...      ...      ...        ...          ...
# 11385      9      7     2374     2436          2          -62
# 11386      9     14     2374     2265         -5          109
# 11387      5      7     2279     2436         -2         -157
# 11388      5     14     2279     2265         -9           14
# 11389      7     14     2436     2265         -7          171
#
# [11390 rows x 6 columns]

# %% [markdown]
# ### Train

# %%
X = tourney_result.drop('result', axis=1)
y = tourney_result.result

# %%
from sklearn.model_selection import KFold
import lightgbm as lgb

# %%
params = {'num_leaves': 470,
          'min_child_weight': 0.034,
          'feature_fraction': 0.379,
          'bagging_fraction': 0.418,
          'min_data_in_leaf': 106,
          'objective': 'binary',
          'max_depth': -1,
          'learning_rate': 0.01,
          "boosting_type": "gbdt",
          "bagging_seed": 11,
          "metric": 'logloss',
          "verbosity": -1,
          'reg_alpha': 0.3899,
          'reg_lambda': 0.648,
          'random_state': 47,
         }

# %%
import gc
NFOLDS = 5
folds = KFold(n_splits=NFOLDS)

columns = X.columns
splits = folds.split(X, y)
y_preds = np.zeros(test_df.shape[0])
y_oof = np.zeros(X.shape[0])

feature_importances = pd.DataFrame()
feature_importances['feature'] = columns
  
for fold_n, (train_index, valid_index) in enumerate(splits):
    print('Fold:',fold_n+1)
    X_train, X_valid = X[columns].iloc[train_index], X[columns].iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
    dtrain = lgb.Dataset(X_train, label=y_train)
    dvalid = lgb.Dataset(X_valid, label=y_valid)

    clf = lgb.train(params, dtrain, 10000, valid_sets = [dtrain, dvalid], verbose_eval=200)
    
    feature_importances[f'fold_{fold_n + 1}'] = clf.feature_importance()
    
    y_pred_valid = clf.predict(X_valid)
    y_oof[valid_index] = y_pred_valid
    
    y_preds += clf.predict(test_df) / NFOLDS
    
    del X_train, X_valid, y_train, y_valid
    gc.collect()
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# ### Predict and Make Submission File

# %%
submission_df = pd.read_csv('../data/raw/MSampleSubmissionStage1_2020.csv')
submission_df['Pred'] = y_preds
submission_df
# Out:
#                    ID      Pred
# 0      2015_1107_1112  0.021326
# 1      2015_1107_1116  0.066854
# 2      2015_1107_1124  0.131908
# 3      2015_1107_1125  0.496461
# 4      2015_1107_1129  0.134024
# ...               ...       ...
# 11385  2019_1449_1459  0.233703
# 11386  2019_1449_1463  0.973068
# 11387  2019_1458_1459  0.527035
# 11388  2019_1458_1463  0.775017
# 11389  2019_1459_1463  0.841662
#
# [11390 rows x 2 columns]

# %%
submission_df['Pred'].hist()

# %%
submission_df.to_csv('../submission.csv', index=False)
